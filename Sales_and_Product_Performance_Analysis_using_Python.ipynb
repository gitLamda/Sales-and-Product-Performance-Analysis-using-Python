# %%
import pandas as pd
import numpy as np
import string
import matplotlib
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %%
products=["Product A","Product B","Product C","Product D","Product E"]
Area=["Colombo","Jaffna","Kandy","Galle","Anuradhapura"]
date=pd.date_range('2022-01-01', '2022-01-31', freq='D')

# %%
#creating probable values for columns in the data frame
def generate_random_prodID():
  return random.choices(products,weights=[0.15,0.32,0.28,0.20,0.05])
def generate_random_sales_quantity():
  return int(random.uniform(50,100))
def generate_random_date():
  return random.choice(date)
def generate_random_area():
  return random.choice(Area)

# %%
#Creating the data frame for 100 records
total_number_of_transactions=100
data=[]
for i in range(total_number_of_transactions):
  row=[]
  row.append(generate_random_prodID())
  row.append(generate_random_sales_quantity())
  row.append(generate_random_date())
  row.append(generate_random_area())
  data.append(row)
df=pd.DataFrame(data,columns=["Product ID","Sales Quan","Transaction Date","Sales Area"])
df
# Out:
#      Product ID  Sales Quan Transaction Date    Sales Area
# 0   [Product C]          75       2022-01-20         Kandy
# 1   [Product C]          98       2022-01-03         Galle
# 2   [Product B]          53       2022-01-21         Kandy
# 3   [Product B]          74       2022-01-10  Anuradhapura
# 4   [Product C]          78       2022-01-27  Anuradhapura
# ..          ...         ...              ...           ...
# 95  [Product A]          58       2022-01-16  Anuradhapura
# 96  [Product E]          96       2022-01-11         Kandy
# 97  [Product C]          57       2022-01-25  Anuradhapura
# 98  [Product B]          74       2022-01-25         Galle
# 99  [Product D]          86       2022-01-27       Colombo
#
# [100 rows x 4 columns]

# %%
#Creating a Pie Chart for Sales Quantity by Area
sales_quan_by_area=df.groupby(["Sales Area"]).sum()
sales_quan_by_area
# Out:
# <ipython-input-5-d56a58717a75>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_quan_by_area=df.groupby(["Sales Area"]).sum()
#               Sales Quan
# Sales Area
# Anuradhapura        1796
# Colombo             1296
# Galle               1565
# Jaffna              1110
# Kandy               1874

# %%
plt.pie(sales_quan_by_area["Sales Quan"],labels=sales_quan_by_area.index)
plt.title("Sales by Region")
plt.show()

# %%
home=[20, 34, 30, 35, 27]
elec=[25, 32, 34, 20, 25]

# %%
#creating a grouped bar chart for Sales by Region
x=np.arange(len(Area))
width=0.35

fig, ax=plt.subplots()
rects1 = ax.bar(x - width/2, home, width, label='Home Supplies')
rects2 = ax.bar(x + width/2, elec, width, label='Electronics')

ax.set_ylabel("Sales")
ax.set_title("Sales for Home Suppies & Electronics by Region")
ax.set_xticks(x)
ax.set_xticklabels(Area)
ax.legend()

fig.tight_layout()

plt.show()

# %%
import plotly.express as px

fig = px.scatter(df, x='Sales Area',y="Sales Quan",title='Product Performance')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2b504f0a-b63c-4ace-8820-06598e743889" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b504f0a-b63c-4ace-8820-06598e743889")) {                    Plotly.newPlot(                        "2b504f0a-b63c-4ace-8820-06598e743889",                        [{"hovertemplate":"Sales Area=%{x}\u003cbr\u003eSales Quan=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Kandy","Galle","Kandy","Anuradhapura","Anuradhapura","Anuradhapura","Galle","Kandy","Colombo","Anuradhapura","Anuradhapura","Colombo","Galle","Anuradhapura","Kandy","Galle","Kandy","Colombo","Anuradhapura","Colombo","Jaffna","Colombo","Anuradhapura","Galle","Galle","Kandy","Jaffna","Colombo","Galle","Colombo","Kandy","Jaffna","Kandy","Galle","Galle","Kandy","Jaffna","Kandy","Kandy","Kandy","Galle","Jaffna","Colombo","Galle","Colombo","Galle","Kandy","Kandy","Kandy","Kandy","Colombo","Kandy","Kandy","Colombo","Jaffna","Kandy","Jaffna","Anuradhapura","Galle","Colombo","Anuradhapura","Galle","Kandy","Galle","Galle","Anuradhapura","Anuradhapura","Kandy","Anuradhapura","Jaffna","Jaffna","Anuradhapura","Kandy","Jaffna","Colombo","Colombo","Anuradhapura","Galle","Jaffna","Anuradhapura","Kandy","Kandy","Anuradhapura","Galle","Anuradhapura","Jaffna","Anuradhapura","Jaffna","Anuradhapura","Jaffna","Colombo","Galle","Jaffna","Colombo","Anuradhapura","Anuradhapura","Kandy","Anuradhapura","Galle","Colombo"],"xaxis":"x","y":[75,98,53,74,78,59,76,81,72,88,92,79,94,69,61,70,60,65,95,77,98,73,53,69,71,56,73,58,77,78,82,64,58,98,56,89,64,92,51,88,57,87,77,81,92,96,97,79,90,97,90,60,60,97,73,66,90,84,66,53,91,94,76,84,64,95,53,61,98,68,53,96,94,74,75,56,74,77,57,99,79,73,64,64,89,86,90,74,82,97,73,99,52,95,58,58,96,57,74,86],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"] ...
